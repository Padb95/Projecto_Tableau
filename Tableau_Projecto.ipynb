# %%
import pandas as pd
import numpy as np

# %%
glopol = pd.read_csv(r"C:\Users\HP\Desktop\Iron Hack\Tableau\Projecto\global air pollution dataset.csv")
glopol
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
liex = pd.read_csv(r"C:\Users\HP\Desktop\Iron Hack\Tableau\Projecto\life_expectancy.csv")
liex
# Out:
#           Country  Year      Status  Population  Hepatitis B  Measles  Polio  \
# 0     Afghanistan  2015  Developing  33736494.0         65.0     1154    6.0
# 1     Afghanistan  2014  Developing    327582.0         62.0      492   58.0
# 2     Afghanistan  2013  Developing  31731688.0         64.0      430   62.0
# 3     Afghanistan  2012  Developing   3696958.0         67.0     2787   67.0
# 4     Afghanistan  2011  Developing   2978599.0         68.0     3013   68.0
# ...           ...   ...         ...         ...          ...      ...    ...
# 2843     Zimbabwe  2004  Developing  12777511.0         68.0       31   67.0
# 2844     Zimbabwe  2003  Developing  12633897.0          7.0      998    7.0
# 2845     Zimbabwe  2002  Developing    125525.0         73.0      304   73.0
# 2846     Zimbabwe  2001  Developing  12366165.0         76.0      529   76.0
# 2847     Zimbabwe  2000  Developing  12222251.0         79.0     1483   78.0
#
# ...

# %%
glopol.isna().sum()
# Out:
# Country               427
# City                    1
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# dtype: int64

# %%
glopol[glopol.isnull() == True]
# Out:
#       Country City  AQI Value AQI Category  CO AQI Value CO AQI Category  \
# 0         NaN  NaN        NaN          NaN           NaN             NaN
# 1         NaN  NaN        NaN          NaN           NaN             NaN
# 2         NaN  NaN        NaN          NaN           NaN             NaN
# 3         NaN  NaN        NaN          NaN           NaN             NaN
# 4         NaN  NaN        NaN          NaN           NaN             NaN
# ...       ...  ...        ...          ...           ...             ...
# 23458     NaN  NaN        NaN          NaN           NaN             NaN
# 23459     NaN  NaN        NaN          NaN           NaN             NaN
# 23460     NaN  NaN        NaN          NaN           NaN             NaN
# 23461     NaN  NaN        NaN          NaN           NaN             NaN
# 23462     NaN  NaN        NaN          NaN           NaN             NaN
#
#        Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category  \
# ...

# %%
glopol.dropna(axis=0, how="any", inplace=True)
glopol
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                         Italy   Priolo Gargallo         66     Moderate
# 3                        Poland         Przasnysz         34         Good
# 4                        France          Punaauia         22         Good
# ...                         ...               ...        ...          ...
# 23458                     India      Gursahaiganj        184    Unhealthy
# 23459                    France            Sceaux         50         Good
# 23460                     India          Mormugao         50         Good
# 23461  United States of America       Westerville         71     Moderate
# 23462                  Malaysia            Marang         70     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %%
glopol.isna().sum()
# Out:
# Country               0
# City                  0
# AQI Value             0
# AQI Category          0
# CO AQI Value          0
# CO AQI Category       0
# Ozone AQI Value       0
# Ozone AQI Category    0
# NO2 AQI Value         0
# NO2 AQI Category      0
# PM2.5 AQI Value       0
# PM2.5 AQI Category    0
# dtype: int64

# %%
glopol[glopol.isnull() == True].sum()
# Out:
# Country                 0
# City                    0
# AQI Value             0.0
# AQI Category            0
# CO AQI Value          0.0
# CO AQI Category         0
# Ozone AQI Value       0.0
# Ozone AQI Category      0
# NO2 AQI Value         0.0
# NO2 AQI Category        0
# PM2.5 AQI Value       0.0
# PM2.5 AQI Category      0
# dtype: object

# %%
glopol.dtypes
# Out:
# Country               object
# City                  object
# AQI Value              int64
# AQI Category          object
# CO AQI Value           int64
# CO AQI Category       object
# Ozone AQI Value        int64
# Ozone AQI Category    object
# NO2 AQI Value          int64
# NO2 AQI Category      object
# PM2.5 AQI Value        int64
# PM2.5 AQI Category    object
# dtype: object

# %%
glopol.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23458    False
# 23459    False
# 23460    False
# 23461    False
# 23462    False
# Length: 23035, dtype: bool

# %%
glopol[glopol.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, City, AQI Value, AQI Category, CO AQI Value, CO AQI Category, Ozone AQI Value, Ozone AQI Category, NO2 AQI Value, NO2 AQI Category, PM2.5 AQI Value, PM2.5 AQI Category]
# Index: []

# %%
glopol = glopol.drop_duplicates()

# %%
glopol.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23458    False
# 23459    False
# 23460    False
# 23461    False
# 23462    False
# Length: 23035, dtype: bool

# %%
glopol.drop_duplicates(inplace=True)

# %%
glopol.to_excel('glopol.xlsx')

# %%
glopol_liex = pd.concat([glopol,liex], axis = 0)
glopol_liex
# Out:
#                  Country              City  AQI Value AQI Category  \
# 0     Russian Federation        Praskoveya       51.0     Moderate
# 1                 Brazil  Presidente Dutra       41.0         Good
# 2                  Italy   Priolo Gargallo       66.0     Moderate
# 3                 Poland         Przasnysz       34.0         Good
# 4                 France          Punaauia       22.0         Good
# ...                  ...               ...        ...          ...
# 2843            Zimbabwe               NaN        NaN          NaN
# 2844            Zimbabwe               NaN        NaN          NaN
# 2845            Zimbabwe               NaN        NaN          NaN
# 2846            Zimbabwe               NaN        NaN          NaN
# 2847            Zimbabwe               NaN        NaN          NaN
#
#       CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# 0              1.0            Good             36.0               Good
# ...

# %%
glopol_liex.to_excel('glopol_liex.xlsx')
